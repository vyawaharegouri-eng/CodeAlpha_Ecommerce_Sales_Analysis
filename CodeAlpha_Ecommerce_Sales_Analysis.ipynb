# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
url = "https://raw.githubusercontent.com/leonism/sample-superstore/master/data/superstore.csv"

df = pd.read_csv(url)

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
url = "https://raw.githubusercontent.com/leonism/sample-superstore/master/data/superstore.csv"
df = pd.read_csv(url)
print("Dataset loaded successfully!")

# %%
print("Missing values:")
print(df.isnull().sum())

# %%
print("Rows and Columns:")
print(df.shape)
# Out:
# Rows and Columns:
# (10800, 21)

# %%
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/leonism/sample-superstore/master/data/superstore.csv"
df = pd.read_csv(url)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         10800 non-null  object
#  1   Order ID       10800 non-null  object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9983 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Row ID             0
# Order ID           0
# Order Date       806
# Ship Date        806
# Ship Mode        806
# Customer ID      806
# Customer Name    806
# Segment          806
# Country          806
# City             806
# State            806
# Postal Code      817
# Region           806
# Product ID       806
# Category         806
# Sub-Category     806
# Product Name     806
# Sales            806
# Quantity         806
# Discount         806
# Profit           806
# dtype: int64

# %%
print("Number of duplicate rows:")
# Out:
# Number of duplicate rows:

# %%
print("Number of duplicate rows:")
print(df.duplicated().sum())
# Out:
# Number of duplicate rows:
# 504

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9983.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55245.233297    229.858001     3.789574     0.156203    28.656896
# std    32038.715955    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    57103.000000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
print("Categories:")
print(df["Category"].unique())
# Out:
# Categories:
# ['Furniture' 'Office Supplies' 'Technology' nan]

# %%
total_profit=df["Profit"].sum()
print("Total Profit:", total_profit)
# Out:
# Total Profit: 286397.0217

# %%
sales_by_category=df.groupby("Category")["Sales"].sum()
print("Sales by Category:")
# Out:
# Sales by Category:

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (10800, 21)
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
sales_by_category=df.groupby("Category")["Sales"].sum()
print("Sales by Category:")
print(sales_by_category)
# Out:
# Sales by Category:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
sales_by_category=df.groupby("Category")["Sales"].sum()
print("Sales by Category:")
print(sales_by_category)
# Out:
# Sales by Category:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
profit_by_category=df.groupby("Category")["Profit"].sum()
print("Profit by Category:")
print(profit_by_category)
# Out:
# Profit by Category:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sales_by_category.plot(kind="bar")

plt.title("tptal sales by Category")
plt.xlabel("Category")
plt.ylabel("sales")
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8, 5))
profit_by_category.plot(kind="bar")

plt.title("Total Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.xticks(rotation=0)
plt.show()

# %%
sales_by_region = df.groupby("Region")["Sales"].sum()
print("Sales by Region:")
print(sales_by_region)
# Out:
# Sales by Region:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sales_by_region.plot(kind="bar")

plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Sales"], bins=30)
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Profit"], bins=30)
plt.title("Distribution of Profit")
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["Sales"], df["Profit"],alpha=0.5)
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# %%
top_products =(
    df.groupby("Product Name")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)
print(top_products)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,6))
top_products.sort_values().plot(kind="barh")
plt.title("Top 10 Products by Sales")
plt.xlabel("Sales")
plt.ylabel("Product")
plt.show()

# %% [markdown]
# ## Key Findings
#
# 1. Sales performance was analyzed across different product categories.
# 2. Profitability was compared across product categories.
# 3. Regional sales patterns were identified.
# 4. The top 10 products by sales were identified.
# 5. The relationship between sales and profit was analyzed.
# 6. Data quality was checked for missing values and duplicate records.
# 7. Visualizations helped identify important sales and profit patterns.

# %% [markdown]
# ## Conclusion
#
# This project analyzed an e-commerce sales dataset using Python.
# Exploratory Data Analysis was used to understand the data, identify
# patterns, and examine sales and profit performance. Data visualization
# was used to present the findings clearly.
#
# The project demonstrates the practical use of Python, Pandas,
# Matplotlib, and Seaborn for data analysis and visualization.
